# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#convert to ascii to get rid of the special characters
df = pd.read_excel('data/sample_data.xlsx', encoding="ascii")

# %%
df.columns
# Out:
# Index(['customer_id', 'gender', 'age', 'total_score', 'industry', 'title',
#        'skills'],
#       dtype='object')

# %%
df.head()
# Out:
#    customer_id gender  age  total_score                             industry  \
# 0            1    NaN  NaN         3.45  Information Technology and Services
# 1            2    NaN  NaN         3.44                             Internet
# 2            3    NaN  0-0        10.49                                  NaN
# 3            4   Male  0-0         3.46                         Construction
# 4            5    NaN  NaN         3.45                                  NaN
#
#                                        title  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3  Functional Architect, Business Technology
# 4                                        NaN
#
#                                               skills
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  SharePoint,Management ,Business Intelligence ,...
# 4                                                NaN

# %%
df.describe()
# Out:
#        customer_id  total_score
# count  5022.000000  5022.000000
# mean   2511.500000     5.853035
# std    1449.870856     3.336261
# min       1.000000     0.450000
# 25%    1256.250000     3.430000
# 50%    2511.500000     3.470000
# 75%    3766.750000    10.460000
# max    5022.000000    10.940000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5022 entries, 0 to 5021
# Data columns (total 7 columns):
# customer_id    5022 non-null int64
# gender         757 non-null object
# age            3009 non-null object
# total_score    5022 non-null float64
# industry       4148 non-null object
# title          2593 non-null object
# skills         2366 non-null object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 274.7+ KB

# %%
print(df.shape)
# Out:
# (5022, 7)

# %%
#check each variable for missing values
print("Total NA:", sum(df.age.isnull().values.ravel()))
print("NA %:", "{:.1%}".format(sum(df.age.isnull().values.ravel())/sum(df.isnull().values.ravel())))
# Out:
# Total NA: 2013
# NA %: 16.5%

# %%
print("Total NA:", sum(df.gender.isnull().values.ravel()))
print("NA %:", "{:.1%}".format(sum(df.gender.isnull().values.ravel())/sum(df.isnull().values.ravel())))
# Out:
# Total NA: 4265
# NA %: 34.9%

# %%
print("Total NA:", sum(df.industry.isnull().values))
print("NA %:", "{:.1%}".format(sum(df.industry.isnull().values.ravel())/sum(df.isnull().values.ravel())))
# Out:
# Total NA: 874
# NA %: 7.1%

# %%
print("Total NA:", sum(df.title.isnull().values))
print("NA %:", "{:.1%}".format(sum(df.title.isnull().values.ravel())/sum(df.isnull().values.ravel())))
# Out:
# Total NA: 2429
# NA %: 19.8%

# %%
print("Total NA:", sum(df.skills.isnull().values))
print("NA %:", "{:.1%}".format(sum(df.skills.isnull().values.ravel())/sum(df.isnull().values.ravel())))
# Out:
# Total NA: 2656
# NA %: 21.7%

# %%
#Cleaning industry

# %%
#slice the industry into a dataframe
df_ind = df[['customer_id','industry']] 
print("Total rows:", df_ind.shape)
print("Total NA:", sum(df_ind.isnull().values))
print("NA %:", "{:.1%}".format(sum(df_ind.isnull().values.ravel())/sum(df_ind.isnull().values.ravel())))
if isinstance(df['industry'], str):
    print("Encoding is ordinary string")
else:
    print("Encoding is not a string")
    
#check the type
print("Encoding is ", type(df['industry']))
df_ind.to_csv('df_ind_initial.csv', sep = ',')
# Out:
# Total rows: (5022, 2)
# Total NA: [  0 874]
# NA %: 100.0%
# Encoding is not a string
# Encoding is  <class 'pandas.core.series.Series'>

# %%
type(df_ind)
# Out:
# pandas.core.frame.DataFrame

# %%
#remove missing values

#df_ind1 = [x for x in df_ind if x != []]

#df_ind = df_ind[np.isfinite(df_ind['industry'])]
df_ind = df_ind[pd.notnull(df_ind['industry'])]

#df_ind = df_ind.dropna(how='all')
print("Total rows:", df_ind.shape)
print("Total NA:", sum(df_ind.isnull().values))
print("NA %:", "{:.1%}".format(sum(df_ind.isnull().values.ravel())/sum(df_ind.isnull().values.ravel())))
df_ind.to_csv('df_ind_no_na.csv', sep = ',')
# Out:
# Total rows: (4148, 2)
# Total NA: [0 0]
# NA %: nan%

# %%
#remove all '_x000D' and '_x000D_' from the beginning of the values

type(df_ind)

df_ind['industry'] = df_ind['industry'].str.replace('_x000D_', '')


df_ind.to_csv('df_ind_no_x000D.csv', sep = ',')

# %%
#DO NOT USE
#remove 'http://' from the beginning of the values

#df_ind['industry'] = df_ind['industry'].str.replace('http', '')
#for i, line in enumerate(df_ind['industry']):
#    if line.startswith('http'):
#        df_ind.drop(line.startswith('http'))
        

#df_ind['industry'] = df_ind[df_ind['industry'].line.startswith('http')]

#print("Total rows:", df_ind.shape)
#df_ind.to_csv('df_ind_no_http.csv', sep = ',')

# %%
#replace '&' with 'AND'
df_ind['industry'] = df_ind['industry'].str.replace("&","AND")
df_ind.to_csv('df_ind_no&.csv', sep = ',')

# %%
#convert all to lowercase
df_ind['industry'] = df_ind.industry.str.lower()
df_ind.head()
df_ind.to_csv('df_ind_lower.csv', sep = ',')

# %%
df_ind = pd.concat([pd.Series(row['customer_id'], row['industry'].split(','))
           for _, row in df_ind.iterrows()]).reset_index()

df_ind.to_csv('df_ind_split.csv', sep = ',')

# %%
#NEEDS TO BE FIXED
#remove whitespace padding from splitted values
df_ind['industry'] = df_ind['industry'].str.lstrip()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/feyzi/anaconda3/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'industry'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-202-888a44f189d0> in <module>()
# ----> 1 df_ind['industry'] = df_ind['industry'].str.lstrip()
#       2
#       3 df_ind.to_csv('df_ind_split.csv', sep = ',')
#
# /Users/feyzi/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /Users/feyzi/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /Users/feyzi/anaconda3/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1348         res = cache.get(item)
#    1349         if res is None:
# -> 1350             values = self._data.get(item)
#    1351             res = self._box_item_values(item, values)
#    1352             cache[item] = res
#
# /Users/feyzi/anaconda3/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3288
#    3289             if not isnull(item):
# -> 3290                 loc = self.items.get_loc(item)
#    3291             else:
#    3292                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/feyzi/anaconda3/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'industry'

# %%
with open(df_ind) as f:
  lis = [x.split() for x in f]

for x in zip(*lis):
  for y in x:
    print(y+'\t', end='')
  print('\n')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-211-83e032dd4910> in <module>()
# ----> 1 with open(df_ind) as f:
#       2   lis = [x.split() for x in f]
#       3
#       4 for x in zip(*lis):
#       5   for y in x:
#
# TypeError: invalid file:                                       index     0
# 0       information technology and services     1
# 1                                  internet     2
# 2                              construction     4
# 3                                    design     6
# 4                              philanthropy     7
# 5                 marketing and advertising     8
# 6                         computer software     9
# 7       search engines and internet portals    10
# 8                        media and internet    10
# 9                                    health    11
# 10                     wellness and fitness    11
# 11                       food and beverages    13
# 12                                 internet    14
# 13                                   health    15
# 14                     wellness and fitness    15
# 15                     information services    18
# 16                                 internet    19
# 17                        computer software    20
# 18                               publishing    21
# 19                                  farming    22
# 20      information technology and services    23
# 21                        computer software    25
# 22                                 internet    26
# 23                       financial services    27
# 24                           computer games    29
# 25    information technologies and services    30
# 26                        computer software    31
# 27                     information services    32
# 28                     information services    33
# 29                    management consulting    34
# ...                                     ...   ...
# 5997                      computer software  4989
# 5998                     financial services  4990
# 5999    information technology and services  4991
# 6000                               internet  4992
# 6001                               internet  4993
# 6002                     data visualization  4993
# 6003                          public safety  4993
# 6004        software development and design  4994
# 6005                               software  4994
# 6006    information technology and services  4995
# 6007                   alternative medicine  4996
# 6008    information technology and services  4997
# 6009              marketing and advertising  4998
# 6010                               internet  4999
# 6011                      computer software  5000
# 6012    information technology and services  5001
# 6013    information technology and services  5002
# 6014                      computer software  5004
# 6015                                leisure  5008
# 6016                     travel and tourism  5008
# 6017                      computer software  5009
# 6018                  management consulting  5010
# 6019                              insurance  5011
# 6020      nonprofit organization management  5012
# 6021                          entertainment  5013
# 6022          civic and social organization  5015
# 6023                      computer software  5017
# 6024                      computer software  5019
# 6025                               internet  5020
# 6026              marketing and advertising  5021
#
# [6027 rows x 2 columns]

# %%
#function for breaking up values into columns
def get_ind(row):
    industries[row] = row.split(',')
    
    return industries

# %%
ind_list = df_ind.apply(get_ind)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-132-579b09877752> in <module>()
# ----> 1 ind_list = df_ind.apply(get_ind)
#
# /Users/feyzi/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4059                     if reduce is None:
#    4060                         reduce = True
# -> 4061                     return self._apply_standard(f, axis, reduce=reduce)
#    4062             else:
#    4063                 return self._apply_broadcast(f, axis)
#
# /Users/feyzi/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4155             try:
#    4156                 for i, v in enumerate(series_gen):
# -> 4157                     results[i] = func(v)
#    4158                     keys.append(v.name)
#    4159             except Exception as e:
#
# <ipython-input-130-98c11fad378e> in get_ind(row)
#       2 def get_ind(row):
#       3     #print(row)
# ----> 4     industries = row.split(',')
#       5     #print(industries)
#       6     return industries
#
# /Users/feyzi/anaconda3/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: ("'Series' object has no attribute 'split'", 'occurred at index customer_id')

# %%
list(ind_list)
# Out:
# [['information technology and services'],
#  ['internet'],
#  ['construction'],
#  ['design'],
#  ['philanthropy'],
#  ['marketing and advertising'],
#  ['computer software'],
#  ['search engines & internet portals', 'media & internet'],
#  ['health', ' wellness and fitness'],
#  ['food & beverages'],
#  ['internet'],
#  ['health', ' wellness and fitness'],
#  ['information services'],
#  ['internet'],
#  ['computer software'],
#  ['publishing'],
#  ['farming'],
#  ['information technology and services'],
#  ['computer software'],
#  ['internet'],
#  ['financial services'],
#  ['computer games'],
#  ['information technologies and services'],
#  ['computer software'],
#  ['information services'],
#  ['information services'],
#  ['management consulting'],
#  ['https://www.linkedin.com/in/franktisellano'],
#  ['advertising & marketing', 'business services'],
#  ['information technology and services'],
#  ['computer software'],
#  ['medical devices'],
#  ['computer software'],
#  ['financial services'],
#  ['marketing and advertising'],
#  ['information technology and services'],
#  ['renewables & environment'],
#  ['e-learning'],
#  ['consumer goods'],
#  ['information technology and services'],
#  ['online media'],
#  ['staffing and recruiting'],
#  ['software development & design', 'software', 'engineering software'],
#  ['publishing'],
#  ['information technology and services'],
#  ['information technology and services'],
#  ['information technology and services'],
#  ['online media'],
#  ['computer software'],
#  ['apparel retail'],
#  ['information technology and services'],
#  ['retail'],
#  ['food production'],
#  ['international affairs'],
#  ['computer software'],
#  ['internet'],
#  ['computer software'],
#  ['computer software'],
#  ['information technology and services'],
#  ['internet service providers',
#   ' website hosting & internet-related services',
#   'telecommunications',
#   'custom software & technical consulting',
#   'software development & design',
#   'business services',
#   'software',
#   'search engines & internet portals',
#   'media & internet'],
#  ['computer software'],
#  ['broadcast media'],
#  ['internet'],
#  ['financial services'],
#  ['computer software'],
#  ['information technology and services'],
#  ['outsourcing/offshoring'],
#  ['human resources'],
#  ['government administration'],
#  ['sports'],
#  ['apparel & fashion'],
#  ['airlines/aviation'],
#  ['computer software'],
#  ['primary/secondary education'],
#  ['insurance'],
#  ['information technology and services'],
#  ['information technology and services'],
#  ['computer software'],
#  ['computer software'],
#  ['health', ' wellness and fitness'],
#  ['computer software'],
#  ['information technology and services'],
#  ['internet'],
#  ['information technology and services'],
#  ['information technology and services'],
#  ['internet'],
#  ['entertainment'],
#  ['financial services'],
#  ['research'],
#  ['human resources'],
#  ['internet'],
#  ['information technology and services'],
#  ['information technology and services'],
#  ['computer software'],
#  ['retail'],
#  ['computer software'],
#  ['computer software'],
#  ['e-learning'],
#  ['computer software'],
#  ['events services'],
#  ['law practice'],
#  ['information technology and services'],
#  ['internet'],
#  ['retail'],
#  ['nonprofit organization management'],
#  ['financial services'],
#  ['internet'],
#  ['fund-raising'],
#  ['computer software'],
#  ['computer games'],
#  ['information technology and services'],
#  ['telecommunications'],
#  ['hospitals & clinics', 'healthcare'],
#  ['oil & energy'],
#  ['software development & design',
#   'software',
#   'engineering software',
#   'business intelligence software(bi)',
#   'enterprise resource planning software(erp)'],
#  ['software development & design', 'software', 'healthcare software'],
#  ['computer software'],
#  ['oil & energy'],
#  ['computer software'],
#  ['marketing and advertising'],
#  ['marketing and advertising'],
#  ['education management'],
#  ['computer software'],
#  ['computer software'],
#  ['internet'],
#  ['international trade and development'],
#  ['information technology and services'],
#  ['computer software'],
#  ['computer & network security'],
#  ['insurance', 'hospitals & clinics', 'healthcare'],
#  ['telecommunications'],
#  ['internet'],
#  ['computer software'],
#  ['internet'],
#  ['information technology and services'],
#  ['membership organizations',
#   'organizations',
#   'custom software & technical consulting',
#   'software'],
#  ['marketing and advertising'],
#  ['computer software'],
#  ['computer software'],
#  ['real estate'],
#  ['computer software'],
#  ['computer software'],
#  ['education management'],
#  ['information technology and services'],
#  ['online media'],
#  ['_x000d_\nbiotechnology'],
#  ['information technology '],
#  ['marketing and advertising'],
#  ['financial services'],
#  ['computer software'],
#  ['consumer services'],
#  ['internet'],
#  ['commercial & residential construction', 'construction'],
#  ['internet'],
#  ['internet\n'],
#  ['computer software'],
#  ['financial services'],
#  ['restaurants'],
#  ['information technology and services'],
#  ['computer software'],
#  ['leisure', ' travel & tourism'],
#  ['computer software'],
#  ['apparel & fashion'],
#  ['financial services'],
#  ['e-learning'],
#  ['internet'],
#  ['computer software'],
#  ['computer software'],
#  ['information technology and services'],
#  ['computer software'],
#  ['computer games'],
#  ['veterinary'],
#  ['information technology and services'],
#  ['education'],
#  ['computer games'],
#  ['consumer electronics',
#   'consumer goods',
#   'manufacturing',
#   'boats & submarines',
#   'commercial & residential construction',
#   'water & water treatment',
#   'construction',
#   'energy',
#   ' utilities & waste treatment',
#   'semiconductor & semiconductor equipment',
#   'electronics'],
#  ['investment banking'],
#  ['computer software'],
#  ['media production'],
#  ['entertainment'],
#  ['computer software'],
#  ['airlines/aviation'],
#  ['internet'],
#  ['banking'],
#  ['media production'],
#  ['marketing and advertising'],
#  ['computer software'],
#  ['information technology and services'],
#  ['computer software'],
#  ['defense & space'],
#  ['transportation/trucking/railroad'],
#  ['broadcast media'],
#  ['internet'],
#  ['biotechnology'],
#  ['computer hardware'],
#  ['entertainment'],
#  ['marketing and advertising'],
#  ['entertainment'],
#  ['computer software'],
#  ['financial services'],
#  ['government administration'],
#  ['design'],
#  ['computer software'],
#  ['computer software'],
#  ['government administration'],
#  ['education management'],
#  ['education management'],
#  ['internet'],
#  ['computer software'],
#  ['computer software'],
#  ['information technology and services'],
#  ['information technology and services'],
#  ['information technology and services'],
#  ['health', ' wellness and fitness'],
#  ['internet'],
#  ['computer software'],
#  ['computer software'],
#  ['computer software'],
#  ['museums and institutions'],
#  ['engineering software', 'software development & design', 'software'],
#  ['fund raising'],
#  ['publishing'],
#  ['information technology and services'],
#  ['computer software'],
#  ['computer software'],
#  ['computer software'],
#  ['internet'],
#  ['accounting'],
#  ['computer software'],
#  ['internet'],
#  ['computer networking'],
#  ['financial services\n'],
#  ['computer software'],
#  ['internet'],
#  ['computer software'],
#  ['government administration\n'],
#  ['leisure', ' travel & tourism\n'],
#  ['restaurants'],
#  ['oil & energy'],
#  ['legal services\n'],
#  ['supermarkets'],
#  ['internet'],
#  ['information technology and services\n'],
#  ['retail'],
#  ['computer games\n'],
#  ['internet'],
#  ['industrial automation\n'],
#  ['internet'],
#  ['software development & design',
#   'software',
#   'engineering software',
#   'business intelligence software(bi)',
#   'enterprise resource planning software(erp)'],
#  ['information technology and services'],
#  ['information technology and services\n'],
#  ['music'],
#  ['computer software'],
#  ['information technology and services\n'],
#  ['online media\n'],
#  ['internet'],
#  ['telecommunications'],
#  ['internet'],
#  ['information technology and services\n'],
#  ['internet'],
#  ['internet'],
#  ['accounting'],
#  ['finance', 'accounting & accounting services', 'business services'],
#  ['marketing and advertising_x000d_\n'],
#  ['information services\n'],
#  ['health', ' wellness and fitness\n'],
#  ['leisure', ' travel & tourism\n'],
#  ['financial services'],
#  ['insurance'],
#  ['internet'],
#  ['internet'],
#  ['computer software'],
#  ['internet'],
#  ['health', ' wellness and fitness\n'],
#  ['internet'],
#  ['printing'],
#  ['primary/secondary education\n'],
#  ['computer software\n'],
#  ['education management\n'],
#  ['information technology and services\n'],
#  ['software development & design',
#   'software',
#   'engineering software',
#   'business intelligence software(bi)',
#   'enterprise resource planning software(erp)'],
#  ['health', ' wellness and fitness'],
#  ['textiles & apparel',
#   'sporting goods',
#   'consumer goods',
#   'advertising & marketing',
#   'sporting & recreational equipment',
#   'business services',
#   'manufacturing',
#   'retail'],
#  ['internet'],
#  ['leisure', ' travel & tourism'],
#  ['information technology and services'],
#  ['hospital and health care'],
#  ['higher education'],
#  ['defense & space'],
#  ['travel agencies & services', 'consumer services'],
#  ['software development & design',
#   'software',
#   'consumer electronics',
#   'consumer goods',
#   'telecommunication equipment',
#   'manufacturing',
#   'engineering software'],
#  ['international trade and development'],
#  ['airlines', ' airports & air services', 'transportation'],
#  ['computer software'],
#  ['information technology and services'],
#  ['internet'],
#  ['computer software'],
#  ['computet software'],
#  ['information technology and services'],
#  ['software development & design',
#   'software',
#   'information & document management',
#   'business services'],
#  ['health', ' wellness and fitness'],
#  ['hospital & health care'],
#  ['software development & design',
#   'software',
#   'engineering software',
#   'business intelligence software(bi)',
#   'enterprise resource planning software(erp)'],
#  ['leisure', ' travel & tourism'],
#  ['airlines', ' airports & air services', 'transportation'],
#  ['human resources'],
#  ['information technology and services'],
#  ['hospital & health care'],
#  ['real estate'],
#  ['financial services'],
#  ['publishing'],
#  ['computer software'],
#  ['marketing and advertising'],
#  ['software development & design',
#   'software',
#   'test & measurement equipment',
#   'manufacturing',
#   'energy',
#   ' utilities & waste treatment'],
#  ['information technology and services'],
#  ['internet'],
#  ['internet'],
#  ['computer software'],
#  ['telecommunications'],
#  ['software development & design',
#   'software',
#   'financial',
#   ' legal & hr software'],
#  ['internet'],
#  ['computer games'],
#  ['marketing and advertising'],
#  ['internet'],
#  ['information technology and services'],
#  ['financial services'],
#  ['computer software'],
#  ['information technology and services'],
#  ['marketing and advertising'],
#  ['sports'],
#  ['medical testing & clinical laboratories',
#   'healthcare',
#   'drug manufacturing & research',
#   'pharmaceuticals',
#   'business services',
#   'biotechnology'],
#  ['computer software'],
#  ['transportation/trucking/railroad'],
#  ['information services'],
#  ['search engines & internet portals', 'media & internet', 'publishing'],
#  ['financial services'],
#  ['information technology and services'],
#  ['financial services'],
#  ['software development & design',
#   'software',
#   'custom software & technical consulting'],
#  ['computer software'],
#  ['information technology and services'],
#  ['research'],
#  ['telecommunications'],
#  ['higher education'],
#  ['software development & design',
#   'software',
#   'engineering software',
#   'content & collaboration software'],
#  ['freight & logistics services', 'transportation'],
#  ['computer software'],
#  ['search engines & internet portals', 'media & internet'],
#  ['accounting'],
#  ['renewables & environment'],
#  ['apparel & accessories',
#   'retail',
#   'textiles & apparel',
#   'consumer goods',
#   'manufacturing'],
#  ['search engines & internet portals', 'media & internet'],
#  ['information technology and services'],
#  ['events services'],
#  ['search engines & internet portals',
#   'media & internet',
#   'apparel & accessories',
#   'retail'],
#  ['telecommunications'],
#  ['manufacturing',
#   'telecommunication equipment',
#   'computer networking equipment',
#   'computer equipment & peripherals',
#   'telecommunications',
#   'internet service providers',
#   ' website hosting & internet-related services'],
#  ['automotive'],
#  ['financial services'],
#  ['call centers & business centers',
#   'business services',
#   'telecommunications'],
#  ['research'],
#  ['information technology and services'],
#  ['libraries'],
#  ['computer software'],
#  ['airlines/aviation'],
#  ['design'],
#  ['computer software'],
#  ['computer & network security'],
#  ['higher education'],
#  ['investment management'],
#  ['writing and editing'],
#  ['consumer electronics', 'consumer goods', 'manufacturing'],
#  ['information technology and services'],
#  ['financial services'],
#  ['petrochemicals',
#   'chemicals',
#   ' petrochemicals',
#   ' glass & gases',
#   'manufacturing',
#   'electricity',
#   ' oil & gas',
#   'energy',
#   ' utilities & waste treatment',
#   'chemicals',
#   'gas stations',
#   ' convenience & liquor stores',
#   'retail'],
#  ['design'],
#  ['information technology and services'],
#  ['public safety'],
#  ['electrical/electronic manufacturing'],
#  ['advertising & marketing',
#   'business services',
#   'software development & design',
#   'software'],
#  ['charitable organizations & foundations', 'organizations'],
#  ['venture capital & private equity'],
#  ['telecommunications'],
#  ['telecommunications'],
#  ['flowers', ' gifts & specialty', 'retail'],
#  ['computer software'],
#  ['financial services'],
#  ['computer software'],
#  ['computer software'],
#  ['software development & design', 'software', 'engineering software'],
#  ['information technology and services'],
#  ['financial services'],
#  ['financial services'],
#  ['banking'],
#  ['transportation/trucking/railroad'],
#  ['computer software'],
#  ['information technology and services'],
#  ['information technology and services'],
#  ['higher education'],
#  ['computer software'],
#  ['internet'],
#  ['publishing', 'media & internet'],
#  ['marketing and advertising'],
#  ['health', ' wellness and fitness'],
#  ['medical devices'],
#  ['software development & design',
#   'software',
#   'custom software & technical consulting',
#   'healthcare software'],
#  ['information technology and services'],
#  ['information technology and services'],
#  ['internet'],
#  ['software development & design',
#   'software',
#   'custom software & technical consulting'],
#  ['environmental services'],
#  ['online media'],
#  ['nonprofit organization management'],
#  ['consumer electronics'],
#  ['airlines/aviation'],
#  ['information technology and services'],
#  ['internet'],
#  ['online media'],
#  ['health', ' wellness and fitness'],
#  ['computer software'],
#  ['information technology and services'],
#  ['computer software'],
#  ['computer networking'],
#  ['computer software'],
#  ['information technology and services'],
#  ['computer software'],
#  ['internet'],
#  ['computer software'],
#  ['online media'],
#  ['automotive'],
#  ['advertising & marketing',
#   'business services',
#   'software development & design',
#   'software',
#   'customer relationship management software(crm)'],
#  ['computer software'],
#  ['software development & design', 'software'],
#  ['information technology and services'],
#  ['software development & design',
#   'software',
#   'engineering software',
#   'business intelligence software(bi)',
#   'enterprise resource planning software(erp)'],
#  ['software development & design',
#   'software',
#   'engineering software',
#   'business intelligence software(bi)',
#   'enterprise resource planning software(erp)'],
#  ['information technology and services'],
#  ['marketing and advertising'],
#  ['travel agencies & services', 'consumer services'],
#  ['information services'],
#  ['studiod'],
#  ['software development & design', 'software', 'engineering software'],
#  ['software development & design',
#   'software',
#   'information & document management',
#   'business services',
#   'business intelligence software(bi)'],
#  ['aviation & aerospace'],
#  ['information technology and services'],
#  ['computer software'],
#  ['software development & design',
#   'software',
#   'engineering software',
#   'business intelligence software(bi)',
#   'enterprise resource planning software(erp)'],
#  ['computer software'],
#  ['internet'],
#  ['software development & design',
#   'software',
#   'engineering software',
#   'consumer electronics',
#   'consumer goods',
#   'telecommunication equipment',
#   'manufacturing'],
#  ['consumer services'],
#  ['hospitals & clinics', 'healthcare'],
#  ['computer software'],
#  ['telecommunications'],
#  ['information technology and services'],
#  ['industrial machinery & equipment', 'manufacturing'],
#  ['internet'],
#  ['airlines/aviation'],
#  ['electrical/electronic manufacturing'],
#  ['internet'],
#  ['marketing and advertising'],
#  ['software development & design',
#   'software',
#   'custom software & technical consulting'],
#  ['training', 'education'],
#  ['medical devices & equipment', 'manufacturing'],
#  ['information technology and services'],
#  ['business supplies and equipment'],
#  ['computer software'],
#  ['health', ' wellness and fitness'],
#  ['computer software'],
#  ['telecommunications'],
#  ['higher education'],
#  ['software development & design',
#   'software',
#   'search engines & internet portals',
#   'media & internet'],
#  ['internet'],
#  ['information technology and services'],
#  ['apps and mobile at pearson'],
#  ['computer software'],
#  ['financial services'],
#  ['information technology and services'],
#  ['information technology and services'],
#  ['online media'],
#  ['computer software'],
#  ['information technology and services'],
#  ['information technology and services'],
#  ['internet'],
#  ['internet'],
#  ['hospital & health care'],
#  ['nonprofit organization management'],
#  ['human resources'],
#  ['information collection & delivery',
#   'media & internet',
#   'internet service providers',
#   ' website hosting & internet-related services',
#   'publishing',
#   'software',
#   'telecommunications',
#   'custom software & technical consulting'],
#  ['software development & design',
#   'software',
#   'consumer electronics',
#   'consumer goods',
#   'telecommunication equipment',
#   'manufacturing',
#   'engineering software'],
#  ['market research'],
#  ['computer software'],
#  ['sporting & recreational equipment', 'retail'],
#  ['government relations'],
#  ['consumer electronics'],
#  ['education management'],
#  ['financial services'],
#  ['automotive'],
#  ['computer software'],
#  ['telephony & wireless', 'telecommunications'],
#  ['nonprofit organization management'],
#  ['media production'],
#  ['marketing and advertising'],
#  ['transportation/trucking/railroad'],
#  ['computer software'],
#  ['software development & design',
#   'software',
#   'engineering software',
#   'consumer electronics',
#   'consumer goods',
#   'telecommunication equipment',
#   'manufacturing'],
#  ['computer software'],
#  ['computer software'],
#  ['gambling & casinos'],
#  ['comnsumer services'],
#  ['information technology and services'],
#  ['internet'],
#  ['mechanical or industrial engineering'],
#  ['computer software'],
#  ['computer software'],
#  ['computer software'],
#  ['computer software'],
#  ['health', ' wellness and fitness'],
#  ['construction'],
#  ['computer software'],
#  ['retail'],
#  ['banking',
#   'finance',
#   'engineering software',
#   'software development & design',
#   'software'],
#  ['higher education'],
#  ['business supplies and equipment'],
#  ['computer software'],
#  ['computer software'],
#  ['computer software'],
#  ['internet'],
#  ['computer software'],
#  ['computer software'],
#  ['software development & design',
#   'software',
#   'radio stations',
#   'broadcasting',
#   'media & internet',
#   'hospitality'],
#  ['computer software'],
#  ['public relations and communications'],
#  ['internet'],
#  ['motor vehicle dealers',
#   'retail',
#   'information collection & delivery',
#   'media & internet'],
#  ['electrical/electronic manufacturing'],
#  ['computer software'],
#  ['software development & design',
#   'software',
#   'engineering software',
#   'business intelligence software(bi)',
#   'enterprise resource planning software(erp)'],
#  ['broadcast media'],
#  ['telecommunications'],
#  ['computer & network security'],
#  ['design'],
#  ['internet'],
#  ['internet'],
#  ['software development & design',
#   'software',
#   'engineering software',
#   'business intelligence software(bi)',
#   'enterprise resource planning software(erp)'],
#  ['e-learning'],
#  ['software development & design',
#   'software',
#   'search engines & internet portals',
#   'media & internet',
#   'content & collaboration software'],
#  ['financial services'],
#  ['television stations',
#   'broadcasting',
#   'media & internet',
#   'cable & satellite',
#   'telecommunications',
#   'movie theaters',
#   'recreation',
#   'hospitality'],
#  ['computer software'],
#  ['outsourcing/offshoring'],
#  ['computer software'],
#  ['software development & design',
#   'software',
#   'engineering software',
#   'financial',
#   ' legal & hr software'],
#  ['software development & design',
#   'software',
#   'custom software & technical consulting',
#   'enterprise resource planning software(erp)'],
#  ['network security hardware & software',
#   'computer equipment & peripherals',
#   'manufacturing',
#   'engineering software',
#   'software development & design',
#   'software'],
#  ['software development & design', 'software', 'engineering software'],
#  ['retail'],
#  ['computer & network security'],
#  ['real estate',
#   'engineering software',
#   'software development & design',
#   'software'],
#  ['software development & design', 'software'],
#  ['information technology and services'],
#  ['internet'],
#  ['computer networking'],
#  ['computer software'],
#  ['television stations',
#   'broadcasting',
#   'publishing',
#   'media & internet',
#   'newspapers & news services',
#   'film/video production & services'],
#  ['software development & design', 'software'],
#  ['software development & design',
#   'software',
#   'engineering software',
#   'customer relationship management software(crm)'],
#  ['public relations and communications'],
#  ['computer software'],
#  ['search engines & internet portals', 'media & internet'],
#  ['banking'],
#  ['financial services'],
#  ['information & document management', 'business services'],
#  ['insurance'],
#  ['computer software'],
#  ['market research'],
#  ['computer software'],
#  ['finance',
#   'banking',
#   'brokerage',
#   'investment banking',
#   'apparel & accessories',
#   'department stores & superstores',
#   'retail',
#   'management consulting',
#   'business services'],
#  ['libraries', ''],
#  ['telecommunications'],
#  ['information technology and services'],
#  ['banking'],
#  ['film/video production & services', 'broadcasting', 'media & internet'],
#  ['computer games'],
#  ['software development & design',
#   'software',
#   'engineering software',
#   'business intelligence software(bi)',
#   'enterprise resource planning software(erp)'],
#  ['consumer services'],
#  ['consumer goods'],
#  ['internet'],
#  ['software development & design',
#   'software',
#   'engineering software',
#   'financial',
#   ' legal & hr software',
#   'enterprise resource planning software(erp)',
#   'customer relationship management software(crm)',
#   'business intelligence software(bi)'],
#  ['electronic components',
#   'electronics',
#   'industrial machinery & equipment',
#   'manufacturing'],
#  ['international trade and development'],
#  ['information technology and services'],
#  ['software development & design', 'software'],
#  ['information technology and services'],
#  ['software development & design',
#   'software',
#   'electronic components',
#   'electronics',
#   'manufacturing',
#   'consumer electronics',
#   'power conversion & protection equipment',
#   'consumer goods',
#   'batteries',
#   ' power storage equipment & generators',
#   'management consulting',
#   'waste treatment',
#   ' environmental services & recycling',
#   'hospitals & clinics',
#   'business services',
#   'energy',
#   ' utilities & waste treatment',
#   'healthcare'],
#  ['aerospace & defense', 'manufacturing', 'electronics'],
#  ['software development & design',
#   'software',
#   'consumer electronics',
#   'consumer goods',
#   'telecommunication equipment',
#   'manufacturing',
#   'engineering software'],
#  ['telecommunications'],
#  ['computer software'],
#  ['human resources & staffing', 'business services'],
#  ['information technology and services'],
#  ['leisure', ' travel & tourism'],
#  ['software development & design',
#   'software',
#   'financial',
#   ' legal & hr software'],
#  ['internet'],
#  ['computer software'],
#  ['business supplies and equipment'],
#  ['colleges & universities', 'education'],
#  ['retail'],
#  ['hospital & health care'],
#  ['software development & design',
#   'software',
#   'engineering software',
#   'business intelligence software(bi)',
#   'enterprise resource planning software(erp)'],
#  ['computer software'],
#  ['telecommunications'],
#  ['information technology and services'],
#  ['computer software'],
#  ['internet'],
#  ['internet'],
#  ['information technology and services'],
#  ['hospital & health care'],
#  ['internet'],
#  ['computer software'],
#  ['marketing and advertising'],
#  ['management consulting'],
#  ['marketing and advertising'],
#  ['internet'],
#  ['leisure', ' travel & tourism'],
#  ['education management'],
#  ['entertainment'],
#  ['computer software'],
#  ['computer software'],
#  ['internet'],
#  ['e-learning_x000d_\n'],
#  ['information technology and services'],
#  ['marketing and advertising'],
#  ['information technology and services'],
#  ['higher education'],
#  ['computer software'],
#  ['consumer electronics'],
#  [' analytics'],
#  ['financial services\n'],
#  ['computer software\n'],
#  ['consumer electronics'],
#  ['internet'],
#  ['oil & energy\n'],
#  ['sports'],
#  ['human resources\n'],
#  ['computer software\n'],
#  ['information technology and services\n'],
#  ['government administration\n'],
#  ['hospitality\n'],
#  ['information technology and services\n'],
#  ['civic & social organization\n'],
#  ['computer software\n'],
#  ['internet'],
#  ['information technology and services\n'],
#  ['information technology and services\n'],
#  ['information technology and services\n'],
#  ['computer software'],
#  ['information technology and services\n'],
#  ['computer software\n'],
#  ['internet'],
#  ['education management\n'],
#  ['hospital & health care\n'],
#  ['real estate'],
#  ['internet'],
#  ['construction'],
#  ['software development & design',
#   'software',
#   'engineering software',
#   'business intelligence software(bi)',
#   'enterprise resource planning software(erp)'],
#  ['information services\n'],
#  ['transportation/trucking/railroad\n'],
#  ['education management\n'],
#  ['internet'],
#  ['accounting'],
#  ['human resources & staffing',
#   'business services',
#   'software development & design',
#   'software',
#   'engineering software'],
#  ['information technology and services\n'],
#  ['marketing and advertising'],
#  ['staffing and recruiting\n'],
#  ['human resources\n'],
#  ['staffing and recruiting'],
#  ['search engine'],
#  ['printing'],
#  ['publishing'],
#  ['information technology and services'],
#  ['marketing and advertising\n'],
#  ['music'],
#  ['nonprofit organization management\n'],
#  ['education management\n'],
#  ['consumer services\n'],
#  ['internet'],
#  ['consumer services\n'],
#  ['engineering software',
#   'software development & design',
#   'software',
#   'retail software'],
#  ['online media\n'],
#  ['internet'],
#  ['nonprofit organization management'],
#  ['computer software'],
#  ['computer software'],
#  ['nonprofit organization management'],
#  ['retail'],
#  ['information services'],
#  ['information & document management',
#   'business services',
#   'custom software & technical consulting',
#   'software'],
#  ['human resources'],
#  ['health', ' wellness and fitness'],
#  ['government administration'],
#  ['internet'],
#  ['greater pittsburgh area'],
#  ['logistics and supply chain'],
#  ['e-learning'],
#  ['internet'],
#  ['information technology and services'],
#  ['computer software'],
#  ['education management'],
#  ['entertainment_x000d_\n'],
#  ['internet'],
#  ['computer software'],
#  ['information technology and services'],
#  ['internet'],
#  ['higher education'],
#  ['financial services'],
#  ['marketing and advertising'],
#  ['medical devices & equipment', 'manufacturing'],
#  ['information technology and services'],
#  ['computer software'],
#  ['information technology and services'],
#  ['computer software'],
#  ['telecommunication equipment',
#   'manufacturing',
#   'software development & design',
#   'software',
#   'telecommunications'],
#  ['_x000d_\nbroadcast media'],
#  ['printing'],
#  ['computer software'],
#  ['hospital & health care'],
#  ['computer software'],
#  ['libraries'],
#  ['computer software'],
#  ['software development & design',
#   'software',
#   'financial',
#   ' legal & hr software',
#   'accounting & accounting services',
#   'business services',
#   'engineering software'],
#  ['computer software'],
#  ['software development & design',
#   'software',
#   'engineering software',
#   'business intelligence software(bi)',
#   'enterprise resource planning software(erp)'],
#  ['music'],
#  ['information technology and services'],
#  ['internet'],
#  ['events services'],
#  ['accounting'],
#  ['automotive'],
#  ['entertainment'],
#  ['information technology and services'],
#  ['internet'],
#  ['infomation tehnologies and services'],
#  ['leisure', ' travel & tourism\n'],
#  ['entertainment'],
#  ['staffing and recruiting'],
#  ['information technology and services'],
#  ['music'],
#  ['computer software'],
#  ['music instrument'],
#  ['internet'],
#  ['computer software'],
#  ['telecommunications', 'telephony & wireless'],
#  ['e-learning'],
#  ['computer software'],
#  ['information technology and services'],
#  ['financial services'],
#  ['nonprofit organization management'],
#  ['consumer services'],
#  ['medical testing & clinical laboratories', 'healthcare'],
#  ['goverment administration'],
#  ['internet'],
#  ['information technology and services'],
#  ['computer software'],
#  ['information technology and services'],
#  ['environmental services'],
#  ['computer software'],
#  ['computer software'],
#  ['telecommunications'],
#  ['utilities'],
#  ['computer software'],
#  ['entertainment'],
#  ['accounting'],
#  ['marketing and advertising'],
#  ['its'],
#  ['marketing and advertising'],
#  ['computer software'],
#  ['media production'],
#  ['computer software'],
#  ['internet'],
#  ['internet'],
#  ['computer software'],
#  ['sports'],
#  ['online media'],
#  ['information technology and services'],
#  ['nonprofit organization management'],
#  ['internet'],
#  ['telecommunication'],
#  ['internet'],
#  ['computer games'],
#  ['consumer electronics'],
#  ['information technology and services'],
#  ['its'],
#  ['internet'],
#  ['computer software'],
#  ['e-learning'],
#  ['internet'],
#  ['human resources'],
#  ['information technology and services'],
#  ['internet'],
#  ['computer software'],
#  ['financial services'],
#  ['computer software'],
#  ['information technology and services'],
#  ['computer software'],
#  ['computer software'],
#  ['higher education'],
#  ['internet'],
#  ['professional training & coaching'],
#  ['computer software'],
#  ['broadcast media'],
#  ['internet'],
#  ['internet'],
#  ['information technology and services'],
#  ['publishing'],
#  ['computer software'],
#  ['computer software'],
#  ['computer software'],
#  ['information technology and services'],
#  ['information technology and services'],
#  ['internet'],
#  ['gambling & casinos'],
#  ['marketing and advertising'],
#  ['information technology and services'],
#  ['real estate'],
#  ['information technology and services'],
#  ['internet'],
#  ['marketing and advertising'],
#  ['internet'],
#  ['marketing and advertising'],
#  ['telecommunications'],
#  ['retail'],
#  ['music'],
#  ['information technology and services'],
#  ['information services'],
#  ['information technology and services'],
#  ['marketing and advertising'],
#  ['marketing and advertising'],
#  ['food & beverages',
#   'food',
#   ' beverages & tobacco',
#   'manufacturing',
#   'music & music related services',
#   'media & internet'],
#  ['computer software'],
#  ['computer software'],
#  ['health', ' wellness and fitness'],
#  ['computer software'],
#  ['telecommunications'],
#  ['internet'],
#  ['real estate'],
#  ['internet'],
#  ['computer software'],
#  ['computer software'],
#  ['information technology and services'],
#  ['online media'],
#  ['internet'],
#  ['telecommunications'],
#  ['business support services'],
#  ['mobile'],
#  ['financial services'],
#  ['financial services'],
#  ['information technology and services'],
#  ['information technology and services'],
#  ['oil & energy'],
#  ['sporting goods'],
#  ['telecommunications'],
#  ['internet'],
#  ['management consulting'],
#  ['marketing and advertising'],
#  ['civic & social organization_x000d_\n'],
#  ['venture capital & private equity'],
#  ['internet'],
#  ['oil & energy_x000d_\n'],
#  ['marketing and advertising_x000d_\n'],
#  ['publishing'],
#  ['information technology and services_x000d_\n'],
#  ['oil & energy'],
#  ['staffing and recruiting'],
#  ['hospitality'],
#  ['computer software'],
#  ['textiles'],
#  ['farming'],
#  ['e-learning'],
#  ['sporting goods_x000d_\n'],
#  ['media production'],
#  ['marketing and advertising_x000d_\n'],
#  ['computer games'],
#  ['computer software'],
#  ['internet'],
#  ['consumer electronics'],
#  ['internet'],
#  ['human resources'],
#  ['medical practice'],
#  ['financial services'],
#  ['computer software'],
#  ['nonprofit organization management'],
#  ['entertainment'],
#  ['human resources'],
#  ['real estate'],
#  ['human resources'],
#  ['leisure', ' travel & tourism'],
#  ['information services\n'],
#  ['computer software'],
#  ['wine and spirits\n'],
#  ['internet'],
#  ['computer software\n'],
#  ['internet'],
#  ['consumer electronics'],
#  ['information technology and services'],
#  ['information technology and services'],
#  ['information technology and services'],
#  ['internet'],
#  ['human resources & staffing', 'business services'],
#  ['information technology and services'],
#  ['financial services\n'],
#  ['information technology and services\n'],
#  ['printing'],
#  ['outsourcing/offshoring'],
#  ['renewables & environment\n'],
#  ['management consulting\n'],
#  ['marketing and advertising\n'],
#  ['computer software'],
#  ['nonprofit organization management\n'],
#  ['information technology and services'],
#  ['electrical/electronic manufacturing'],
#  ['software development & design',
#   'software',
#   'engineering software',
#   'business intelligence software(bi)',
#   'enterprise resource planning software(erp)'],
#  ['computer software'],
#  ['computer software'],
#  ['computer software'],
#  ['retail'],
#  ['computer software\n'],
#  ['computer software'],
#  ['online media'],
#  ['marketing and advertising\n'],
#  ['e-learning'],
#  ['computer software\n'],
#  ['internet'],
#  ['broadcast media'],
#  ['computer games'],
#  ['food & beverages\n'],
#  ['machinery'],
#  ['computer software'],
#  ['market research'],
#  ['airlines/aviation'],
#  ['information services'],
#  ['medical practice\n'],
#  ['religious institutions'],
#  ['software development & design',
#   'software',
#   'network security hardware & software',
#   'computer equipment & peripherals',
#   'manufacturing',
#   'consumer electronics',
#   'consumer goods',
#   'business services',
#   'engineering software'],
#  ['finance app you can carry in your pocket'],
#  ['computer software'],
#  ['apparel & accessories', 'retail'],
#  ['information technology and services'],
#  ['marketing and advertising'],
#  ['leisure', ' travel & tourism'],
#  ['computer software'],
#  ['apparel & fashion'],
#  ['computer software'],
#  ['software development & design', 'software'],
#  ['computer software'],
#  ['oil & energy\n'],
#  ['publishing', 'media & internet'],
#  ['computer software'],
#  ['marketing and advertising'],
#  ['professional training & coaching'],
#  ['construction'],
#  ['consumer services\n'],
#  ['internet'],
#  ['information technology and services'],
#  ['legal services'],
#  ['online advertising'],
#  ['computer software'],
#  ['internet'],
#  ['consumer goods'],
#  ['government administration'],
#  ['information technology and services'],
#  ['computer games'],
#  ['higher education'],
#  ['information technology and services'],
#  ['internet'],
#  ['information technology and services'],
#  ['internet'],
#  ['internet'],
#  ['computer software'],
#  ['e-learning'],
#  ['information technology and services'],
#  ['financial services'],
#  ['computer software'],
#  ['computer software'],
#  ['insurance'],
#  ['greater boston area'],
#  ['information technology and services'],
#  ['providence', ' rhode island area'],
#  ['entertainment'],
#  ['custom software & technical consulting',
#   'software',
#   'information collection & delivery',
#   'media & internet'],
#  ['computer software'],
#  ['legal services'],
#  ['san francisco bay area'],
#  ['internet'],
#  ['food & beverages'],
#  ['financial services'],
#  ['information technology and services'],
#  ['internet'],
#  ['nonprofit organization management'],
#  ['internet'],
#  ...]

# %%
ind_flat = lambda l: [item for sublist in l for item in sublist]

# %%
#flatten the list and remove duplicates

ind_flat_ls = list(set(ind_flat(ind_list))) 

#remove whitespaces _x000D, special characters, convert to the same case

# %%
#apply the industry column names
df1 = pd.DataFrame(columns = ind_flat_ls) 
df1.head()
# Out:
# Empty DataFrame
# Columns: [, Health & Nutrition Products, Newspapers, Application Software , Aviation & Aerospace, Computer Software, Sporting Goods, Internet Software, Insurance_x000D_
# , Retail, Home Furnishing Retail, Health, Computer Networking, Human Resources
# ,  Data Visualization, Finance App you can carry in your pocket, Education Management
# , Grocery, Defense & Space, studioD, Acounting, Movies & Entertainment, Translation and Localization, Graphic Design,  Oil & Gas, marketing and advertising, Colleges, Telecommunication, Jewelry & Watches, civil engineering, staffing and recruiting, Restaurants, Human recources, Construction, Medical Practice, Market Research_x000D_
# , Online Media
# , Broadcast Media, Finance, Cable & Satellite, Program Development, Industrial Automation, Compter Software, music, Food,  Advertising, Food & Beverages
# , food and beverage, Accounting & Accounting Services, Primary/Secondary Education, Water & Water Treatment, Public Relations and Communications, Capital Markets,  Bus & Taxi, Media company, Mobile Applications, Radio Stations, Market Research,  Website Hosting & Internet-related Services, Boats & Submarines,  Legal & HR Software, Information Services, Civic & Social Organization, Social network, computet software, design, Oil & Energy, Online media,  Travel & Tourism, Furniture, Newspapers & News Services, Medical Practice
# , Engineering Software, Music & Music Related Services, Providence,  Energy, Bachelor of Business Administration (B.B.A.),  Convenience & Liquor Stores, Architecture,  Natural Gas,  Recruiti,  Engineering & Design, Plastics, Mechanical or Industrial Engineering, E-Learning_x000D_
# , Sports Teams & Leagues, Facilities Management & Commercial Cleaning,  Rhode Island Area, Civic & Social Organization_x000D_
# , Entertainment_x000D_
# , ITS, Computer Equipment & Peripherals,  Inc, Government Administration_x000D_
# , Lifestyle, International Affairs, information Technology and Services, Universities, Staffing and Recruiting, Business Services, ...]
# Index: []
#
# [0 rows x 474 columns]

# %%
old_cols = df.columns

# %%
required_cols = ['customer_id','total_score']
ind_flat_ls.extend(required_cols)
df_ind_added = pd.DataFrame(columns=ind_flat_ls)

# %%
df_ind_added.head()
# Out:
# Empty DataFrame
# Columns: [, Health & Nutrition Products, Newspapers, Application Software , Aviation & Aerospace, Computer Software, Sporting Goods, Internet Software, Insurance_x000D_
# , Retail, Home Furnishing Retail, Health, Computer Networking, Human Resources
# ,  Data Visualization, Finance App you can carry in your pocket, Education Management
# , Grocery, Defense & Space, studioD, Acounting, Movies & Entertainment, Translation and Localization, Graphic Design,  Oil & Gas, marketing and advertising, Colleges, Telecommunication, Jewelry & Watches, civil engineering, staffing and recruiting, Restaurants, Human recources, Construction, Medical Practice, Market Research_x000D_
# , Online Media
# , Broadcast Media, Finance, Cable & Satellite, Program Development, Industrial Automation, Compter Software, music, Food,  Advertising, Food & Beverages
# , food and beverage, Accounting & Accounting Services, Primary/Secondary Education, Water & Water Treatment, Public Relations and Communications, Capital Markets,  Bus & Taxi, Media company, Mobile Applications, Radio Stations, Market Research,  Website Hosting & Internet-related Services, Boats & Submarines,  Legal & HR Software, Information Services, Civic & Social Organization, Social network, computet software, design, Oil & Energy, Online media,  Travel & Tourism, Furniture, Newspapers & News Services, Medical Practice
# , Engineering Software, Music & Music Related Services, Providence,  Energy, Bachelor of Business Administration (B.B.A.),  Convenience & Liquor Stores, Architecture,  Natural Gas,  Recruiti,  Engineering & Design, Plastics, Mechanical or Industrial Engineering, E-Learning_x000D_
# , Sports Teams & Leagues, Facilities Management & Commercial Cleaning,  Rhode Island Area, Civic & Social Organization_x000D_
# , Entertainment_x000D_
# , ITS, Computer Equipment & Peripherals,  Inc, Government Administration_x000D_
# , Lifestyle, International Affairs, information Technology and Services, Universities, Staffing and Recruiting, Business Services, ...]
# Index: []
#
# [0 rows x 476 columns]

# %%
#check columns 
df_ind.head()
#df_ind.columns
# Out:
# 0    0       0                     Information Tech...
# 1    0       0                     Information Tech...
# 2    0       0                     Information Tech...
# 3    0       0                     Information Tech...
# 4    0       0                     Information Tech...
# Name: industry, dtype: object
